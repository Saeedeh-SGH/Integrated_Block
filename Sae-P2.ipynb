# %%
from pytorch_pretrained_bert import BertTokenizer, BertModel, BertForMaskedLM

# Load pre-trained model tokenizer (vocabulary)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Tokenized input
text1 = "This is Saeedeh. I am a student at the university of Alberta."
text2 = "I am Saeedeh."
tokenized_text1 = tokenizer.tokenize(text1)
tokenized_text2 = tokenizer.tokenize(text2)
print(tokenized_text1)
print(tokenized_text2)

['this', 'is', 'sa', '##eed', '##eh', '.', 'i', 'am', 'a', 'student', 'at', 'the', 'university', 'of', 'alberta', '.']
['i', 'am', 'sa', '##eed', '##eh', '.']

from bert_serving.client import BertClient
from sklearn.metrics.pairwise import cosine_similarity

# Uncomment the following line if the BERT server that is running locally (on the same physical server that the client will be running on).
print('before client')
client = BertClient()

# Uncomment the following line if the BERT server is running remotely (on a different physical server than the client will be running on).
# You must specify the IP of the remote server and the ports

#client = BertClient(ip='129.128.208.15')
print('after client')

before client

from bert_serving.client import BertClient

ls

bert_config.json                     bert_model.ckpt.index  vocab.txt
bert_model.ckpt.data-00000-of-00001  bert_model.ckpt.meta

pwd

/home/ubuntu/anaconda3/lib/python3.7/site-packages

'/home/ubuntu/virt-env/jupyterNB'

 

pip install https://storage.googleapis.com/cloud-tpu-checkpoints/albert/checkpoints/albert_v2_base.tar.gz

Collecting https://storage.googleapis.com/cloud-tpu-checkpoints/albert/checkpoints/albert_v2_base.tar.gz
  Using cached https://storage.googleapis.com/cloud-tpu-checkpoints/albert/checkpoints/albert_v2_base.tar.gz (44.0 MB)
    ERROR: Command errored out with exit status 1:
     command: /home/ubuntu/anaconda3/bin/python -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-req-build-1vhf0yv8/setup.py'"'"'; __file__='"'"'/tmp/pip-req-build-1vhf0yv8/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-s9ct478j
         cwd: /tmp/pip-req-build-1vhf0yv8/
    Complete output (5 lines):
    Traceback (most recent call last):
      File "<string>", line 1, in <module>
      File "/home/ubuntu/anaconda3/lib/python3.7/tokenize.py", line 447, in open
        buffer = _builtin_open(filename, 'rb')
    FileNotFoundError: [Errno 2] No such file or directory: '/tmp/pip-req-build-1vhf0yv8/setup.py'
    ----------------------------------------
ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
Note: you may need to restart the kernel to use updated packages.

pip install tf-nightly-gpu

Collecting tf-nightly-gpu
  Downloading tf_nightly_gpu-2.4.0.dev20200707-cp37-cp37m-manylinux2010_x86_64.whl (322.7 MB)
     |████████████████████████████████| 322.7 MB 2.9 kB/s  eta 0:00:01     |██████████▉                     | 108.8 MB 19.9 MB/s eta 0:00:11     |█████████████████████████████▎  | 294.9 MB 53.2 MB/s eta 0:00:01
Requirement already satisfied: tf-estimator-nightly in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tf-nightly-gpu) (2.4.0.dev2020070601)
Requirement already satisfied: six>=1.12.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tf-nightly-gpu) (1.12.0)
Requirement already satisfied: astunparse==1.6.3 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tf-nightly-gpu) (1.6.3)
Requirement already satisfied: opt-einsum>=2.3.2 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tf-nightly-gpu) (3.2.1)
Requirement already satisfied: tb-nightly<2.4.0a0,>=2.3.0a0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tf-nightly-gpu) (2.3.0a20200706)
Requirement already satisfied: gast==0.3.3 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tf-nightly-gpu) (0.3.3)
Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tf-nightly-gpu) (2.10.0)
Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tf-nightly-gpu) (1.1.2)
Requirement already satisfied: wrapt>=1.11.1 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tf-nightly-gpu) (1.11.2)
Requirement already satisfied: grpcio>=1.8.6 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tf-nightly-gpu) (1.30.0)
Requirement already satisfied: termcolor>=1.1.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tf-nightly-gpu) (1.1.0)
Requirement already satisfied: protobuf>=3.9.2 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tf-nightly-gpu) (3.12.2)
Requirement already satisfied: numpy<1.19.0,>=1.16.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tf-nightly-gpu) (1.17.2)
Requirement already satisfied: wheel>=0.26 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tf-nightly-gpu) (0.33.6)
Requirement already satisfied: absl-py>=0.7.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tf-nightly-gpu) (0.9.0)
Requirement already satisfied: google-pasta>=0.1.8 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tf-nightly-gpu) (0.2.0)
Requirement already satisfied: scipy==1.4.1 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tf-nightly-gpu) (1.4.1)
Requirement already satisfied: markdown>=2.6.8 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (3.2.2)
Requirement already satisfied: google-auth<2,>=1.6.3 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (1.18.0)
Requirement already satisfied: werkzeug>=0.11.15 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (0.16.0)
Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (0.4.1)
Requirement already satisfied: setuptools>=41.0.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (49.1.0)
Requirement already satisfied: requests<3,>=2.21.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (2.22.0)
Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (1.6.0.post3)
Requirement already satisfied: importlib-metadata; python_version < "3.8" in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from markdown>=2.6.8->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (0.23)
Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (4.1.0)
Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (0.2.8)
Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (4.6)
Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (1.3.0)
Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (2019.9.11)
Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (3.0.4)
Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (1.24.2)
Requirement already satisfied: idna<2.9,>=2.5 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (2.8)
Requirement already satisfied: zipp>=0.5 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (0.6.0)
Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (0.4.8)
Requirement already satisfied: oauthlib>=3.0.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (3.1.0)
Requirement already satisfied: more-itertools in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from zipp>=0.5->importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly-gpu) (7.2.0)
Installing collected packages: tf-nightly-gpu
Successfully installed tf-nightly-gpu-2.4.0.dev20200707
Note: you may need to restart the kernel to use updated packages.

pip install albert-tensorflow

Collecting albert-tensorflow
  Downloading albert_tensorflow-1.1-py3-none-any.whl (81 kB)
     |████████████████████████████████| 81 kB 893 kB/s eta 0:00:011
Requirement already satisfied: six in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from albert-tensorflow) (1.12.0)
Installing collected packages: albert-tensorflow
Successfully installed albert-tensorflow-1.1
Note: you may need to restart the kernel to use updated packages.

pip install bert-serving-server

Requirement already satisfied: bert-serving-server in /home/ubuntu/anaconda3/lib/python3.7/site-packages (1.10.0)
Requirement already satisfied: numpy in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from bert-serving-server) (1.17.2)
Requirement already satisfied: pyzmq>=17.1.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from bert-serving-server) (18.1.0)
Requirement already satisfied: six in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from bert-serving-server) (1.12.0)
Requirement already satisfied: GPUtil>=1.3.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from bert-serving-server) (1.4.0)
Requirement already satisfied: termcolor>=1.1 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from bert-serving-server) (1.1.0)
Note: you may need to restart the kernel to use updated packages.

bert-serving-server -model_dir /uncased_bert_model -num_worker 4

  File "<ipython-input-22-993cf4e01acd>", line 1
    tar -xvzf bert-serving-start.tar.gz
                 ^
SyntaxError: invalid syntax

from bert_serving.client import BertClient
client = BertClient()

---------------------------------------------------------------------------
KeyboardInterrupt                         Traceback (most recent call last)
<ipython-input-37-0426c3497f7a> in <module>
      1 from bert_serving.client import BertClient
----> 2 client = BertClient()

~/anaconda3/lib/python3.7/site-packages/bert_serving/client/__init__.py in __init__(self, ip, port, port_out, output_fmt, show_server_config, identity, check_version, check_length, check_token_info, ignore_all_checks, timeout)
    106 
    107         if not ignore_all_checks and (check_version or show_server_config or check_length or check_token_info):
--> 108             s_status = self.server_config
    109 
    110             if check_version and s_status['server_version'] != self.status['client_version']:

~/anaconda3/lib/python3.7/site-packages/bert_serving/client/__init__.py in arg_wrapper(self, *args, **kwargs)
    204                 self.receiver.setsockopt(zmq.RCVTIMEO, self.timeout)
    205             try:
--> 206                 return func(self, *args, **kwargs)
    207             except zmq.error.Again as _e:
    208                 t_e = TimeoutError(

~/anaconda3/lib/python3.7/site-packages/bert_serving/client/__init__.py in server_config(self)
    230         """
    231         req_id = self._send(b'SHOW_CONFIG')
--> 232         return jsonapi.loads(self._recv(req_id).content[1])
    233 
    234     @property

~/anaconda3/lib/python3.7/site-packages/bert_serving/client/__init__.py in _recv(self, wait_for_req_id)
    151 
    152                 # receive a response
--> 153                 response = self.receiver.recv_multipart()
    154                 request_id = int(response[-1])
    155 

~/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
    473             for any of the reasons :func:`~Socket.recv` might fail
    474         """
--> 475         parts = [self.recv(flags, copy=copy, track=track)]
    476         # have first part already, only loop while more to receive
    477         while self.getsockopt(zmq.RCVMORE):

zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()

zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()

zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()

~/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()

KeyboardInterrupt: 

from bert_serving.client import BertClient
bc = BertClient()
print("Yaaaaay")

# !pip install https://storage.googleapis.com/bert_models/2018_10_18/cased_L-12_H-768_A-12.zip

Collecting https://storage.googleapis.com/bert_models/2018_10_18/cased_L-12_H-768_A-12.zip
  Cache entry deserialization failed, entry ignored
  Downloading https://storage.googleapis.com/bert_models/2018_10_18/cased_L-12_H-768_A-12.zip (404.3MB)
    100% |████████████████████████████████| 404.3MB 3.6kB/s  eta 0:00:01  10% |███▌                            | 44.4MB 27.3MB/s eta 0:00:14    15% |█████                           | 64.5MB 22.8MB/s eta 0:00:15    24% |███████▉                        | 99.4MB 27.4MB/s eta 0:00:12    36% |███████████▊                    | 147.7MB 27.3MB/s eta 0:00:10    36% |███████████▉                    | 149.1MB 27.1MB/s eta 0:00:10    38% |████████████▍                   | 157.0MB 24.5MB/s eta 0:00:11    45% |██████████████▌                 | 183.7MB 23.9MB/s eta 0:00:10    47% |███████████████                 | 190.2MB 23.5MB/s eta 0:00:10    47% |███████████████▏                | 191.7MB 37.4MB/s eta 0:00:06    49% |████████████████                | 201.1MB 27.0MB/s eta 0:00:08    50% |████████████████▏               | 203.8MB 25.3MB/s eta 0:00:08    52% |████████████████▉               | 212.7MB 16.6MB/s eta 0:00:12��█████████████████▋           | 260.2MB 48.1MB/s eta 0:00:03/s eta 0:00:03    74% |████████████████████████        | 302.3MB 51.0MB/s eta 0:00:03
    Complete output from command python setup.py egg_info:
    Traceback (most recent call last):
      File "<string>", line 1, in <module>
      File "/usr/lib/python3.6/tokenize.py", line 452, in open
        buffer = _builtin_open(filename, 'rb')
    FileNotFoundError: [Errno 2] No such file or directory: '/tmp/pip-38q0f_1c-build/setup.py'
    
    ----------------------------------------
Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-38q0f_1c-build/

ls

classifier_utils.py  optimization.py               run_pretraining.py
__init__.py          optimization_test.py          run_squad.py
lamb_optimizer.py    __pycache__/                  squad_utils.py
modeling.py          run_classifier.py             tokenization.py
modeling_test.py     run_classifier_with_tfhub.py  tokenization_test.py

pwd

'/home/ubuntu/anaconda3/lib/python3.7/site-packages'

# !bert-serving-start -model_dir uncased_L-24_H-1024_A-16

/home/ubuntu/anaconda3/lib/python3.7/site-packages/bert_serving/server/helper.py:176: UserWarning: Tensorflow 2.2.0 is not tested! It may or may not work. Feel free to submit an issue at https://github.com/hanxiao/bert-as-service/issues/
  'Feel free to submit an issue at https://github.com/hanxiao/bert-as-service/issues/' % tf.__version__)
usage: /home/ubuntu/anaconda3/bin/bert-serving-start -model_dir uncased_L-24_H-1024_A-16
                 ARG   VALUE
__________________________________________________
           ckpt_name = bert_model.ckpt
         config_name = bert_config.json
                cors = *
                 cpu = False
          device_map = []
       do_lower_case = True
  fixed_embed_length = False
                fp16 = False
 gpu_memory_fraction = 0.5
       graph_tmp_dir = None
    http_max_connect = 10
           http_port = None
        mask_cls_sep = False
      max_batch_size = 256
         max_seq_len = 25
           model_dir = uncased_L-24_H-1024_A-16
no_position_embeddings = False
    no_special_token = False
          num_worker = 1
       pooling_layer = [-2]
    pooling_strategy = REDUCE_MEAN
                port = 5555
            port_out = 5556
       prefetch_size = 10
 priority_batch_size = 16
show_tokens_to_client = False
     tuned_model_dir = None
             verbose = False
                 xla = False

I:VENTILATOR:[__i:__i: 67]:freeze, optimize and export graph, could take a while...
I:GRAPHOPT:[gra:opt: 53]:model config: uncased_L-24_H-1024_A-16/bert_config.json
I:GRAPHOPT:[gra:opt: 56]:checkpoint: uncased_L-24_H-1024_A-16/bert_model.ckpt
I:GRAPHOPT:[gra:opt: 60]:build graph...
E:GRAPHOPT:[gra:opt:154]:fail to optimize the graph!
Traceback (most recent call last):
  File "/home/ubuntu/anaconda3/lib/python3.7/site-packages/bert_serving/server/graph.py", line 62, in optimize_graph
    input_ids = tf.placeholder(tf.int32, (None, None), 'input_ids')
AttributeError: module 'tensorflow' has no attribute 'placeholder'
Traceback (most recent call last):
  File "/home/ubuntu/anaconda3/bin/bert-serving-start", line 10, in <module>
    sys.exit(main())
  File "/home/ubuntu/anaconda3/lib/python3.7/site-packages/bert_serving/server/cli/__init__.py", line 4, in main
    with BertServer(get_run_args()) as server:
  File "/home/ubuntu/anaconda3/lib/python3.7/site-packages/bert_serving/server/__init__.py", line 71, in __init__
    self.graph_path, self.bert_config = pool.apply(optimize_graph, (self.args,))
TypeError: cannot unpack non-iterable NoneType object

# !pip install Keras==2.3.1

Collecting Keras==2.3.1
  Downloading Keras-2.3.1-py2.py3-none-any.whl (377 kB)
     |████████████████████████████████| 377 kB 1.8 MB/s eta 0:00:01
Requirement already satisfied: numpy>=1.9.1 in /home/ubuntu/virt-env/lib/python3.6/site-packages (from Keras==2.3.1) (1.19.0)
Requirement already satisfied: keras-applications>=1.0.6 in /home/ubuntu/virt-env/lib/python3.6/site-packages (from Keras==2.3.1) (1.0.8)
Requirement already satisfied: h5py in /home/ubuntu/virt-env/lib/python3.6/site-packages (from Keras==2.3.1) (2.10.0)
Collecting pyyaml
  Downloading PyYAML-5.3.1.tar.gz (269 kB)
     |████████████████████████████████| 269 kB 5.5 MB/s eta 0:00:01
Requirement already satisfied: scipy>=0.14 in /home/ubuntu/virt-env/lib/python3.6/site-packages (from Keras==2.3.1) (1.4.1)
Requirement already satisfied: keras-preprocessing>=1.0.5 in /home/ubuntu/virt-env/lib/python3.6/site-packages (from Keras==2.3.1) (1.1.2)
Requirement already satisfied: six>=1.9.0 in /home/ubuntu/virt-env/lib/python3.6/site-packages (from Keras==2.3.1) (1.15.0)
Building wheels for collected packages: pyyaml
  Building wheel for pyyaml (setup.py) ... done
  Created wheel for pyyaml: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=44621 sha256=175b8c4bf37d85c83379df175582179f7d26416574b2d140a631f673fcd7b80a
  Stored in directory: /home/ubuntu/.cache/pip/wheels/e5/9d/ad/2ee53cf262cba1ffd8afe1487eef788ea3f260b7e6232a80fc
Successfully built pyyaml
Installing collected packages: pyyaml, Keras
Successfully installed Keras-2.3.1 pyyaml-5.3.1

cd anaconda3/lib/python3.7/site-packages

/home/ubuntu/anaconda3/lib/python3.7/site-packages

print(Keras.__version__)

---------------------------------------------------------------------------
NameError                                 Traceback (most recent call last)
<ipython-input-35-7bcf3b4d5c4a> in <module>
----> 1 print(Keras.__version__)

NameError: name 'Keras' is not defined

import tensorflow as tf
print(tf.__version__)

2.4.0-dev20200707

# !wget https://storage.googleapis.com/bert_models/2018_10_18/uncased_L-24_H-1024_A-16.zip -O temp.zip

--2020-07-10 22:11:06--  https://storage.googleapis.com/bert_models/2018_10_18/uncased_L-24_H-1024_A-16.zip
Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.14.208, 172.217.14.240, 2607:f8b0:400a:801::2010, ...
Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.14.208|:443... connected.
HTTP request sent, awaiting response... 200 OK
Length: 1247797031 (1.2G) [application/zip]
Saving to: ‘temp.zip’

temp.zip            100%[===================>]   1.16G  69.0MB/s    in 19s     

2020-07-10 22:11:25 (63.9 MB/s) - ‘temp.zip’ saved [1247797031/1247797031]

# !unzip temp.zip

Archive:  temp.zip
   creating: uncased_L-24_H-1024_A-16/
  inflating: uncased_L-24_H-1024_A-16/bert_model.ckpt.meta  
  inflating: uncased_L-24_H-1024_A-16/bert_model.ckpt.data-00000-of-00001  
  inflating: uncased_L-24_H-1024_A-16/vocab.txt  
  inflating: uncased_L-24_H-1024_A-16/bert_model.ckpt.index  
  inflating: uncased_L-24_H-1024_A-16/bert_config.json  

# !rm temp.zip

cd anaconda3/lib/python3.7/site-packages

/home/ubuntu/anaconda3/lib/python3.7/site-packages

cd anaconda3/lib/python3.7/site-packages

/home/ubuntu/anaconda3/lib/python3.7/site-packages

# !sed -i 's/tf.logging/tf.compat.v1.logging/g' bert_serving/server/helper.py

# !sed -i 's/tf.ConfigProto/tf.compat.v1.ConfigProto/g' bert_serving/server/graph.py

# !sed -i 's/tf.gfile/tf.io.gfile/g' bert_serving/server/graph.py

# !chmod a+rwx bert_serving/server/graph.py

ls -l bert_serving/server/graph.py

ls

absl/
absl_py-0.9.0.dist-info/
alabaster/
alabaster-0.7.12.dist-info/
albert/
albert_tensorflow-1.1.dist-info/
anaconda_client-1.7.2-py3.7.egg-info/
anaconda_navigator/
anaconda_navigator-1.9.7-py3.7.egg-info/
anaconda_project/
anaconda_project-0.8.3.dist-info/
apiclient/
asn1crypto/
asn1crypto-1.0.1.dist-info/
astor/
astor-0.8.1.dist-info/
astroid/
astroid-2.3.1.dist-info/
astropy/
astropy-3.2.2-py3.7.egg-info/
tornado/
tornado-6.0.3.dist-info/
tqdm/
tqdm-4.36.1.dist-info/
traitlets/
traitlets-4.3.3.dist-info/
tree/
typeguard/
typeguard-2.9.1.dist-info/
typing-3.7.4.1.dist-info/
typing.py
uncased_L-24_H-1024_A-16/
unicodecsv/
unicodecsv-0.14.1-py3.7.egg-info/
uritemplate/
uritemplate-3.0.1.dist-info/
urllib3/
urllib3-1.25.9.dist-info/
wcwidth/
wcwidth-0.1.7-py3.7.egg-info/
webencodings/
webencodings-0.5.1-py3.7.egg-info/
werkzeug/
Werkzeug-1.0.1.dist-info/
wheel/
wheel-0.34.2.dist-info/
widgetsnbextension/
widgetsnbextension-3.5.1.dist-info/
wrapt/
wrapt-1.12.1.dist-info/
wurlitzer-1.0.3.dist-info/
wurlitzer.py
xlrd/
xlrd-1.2.0.dist-info/
xlsxwriter/
XlsxWriter-1.2.1.dist-info/
xlwt/
xlwt-1.3.0-py3.7.egg-info/
xontrib/
yaml/
_yaml.cpython-37m-x86_64-linux-gnu.so*
zict/
zict-1.0.0-py2.7.egg-info/
zipp-3.1.0.dist-info/
zipp.py
zmq/

import tensorflow as tf
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

---------------------------------------------------------------------------
AttributeError                            Traceback (most recent call last)
<ipython-input-7-3141dce84fad> in <module>
----> 1 import tensorflow as tf
      2 physical_devices = tf.config.experimental.list_physical_devices('GPU')
      3 tf.config.experimental.set_memory_growth(physical_devices[0], True)

~/anaconda3/lib/python3.7/site-packages/tensorflow/__init__.py in <module>
     39 import sys as _sys
     40 
---> 41 from tensorflow.python.tools import module_util as _module_util
     42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
     43 

~/anaconda3/lib/python3.7/site-packages/tensorflow/python/__init__.py in <module>
     82 from tensorflow.python import data
     83 from tensorflow.python import distribute
---> 84 from tensorflow.python import keras
     85 from tensorflow.python.feature_column import feature_column_lib as feature_column
     86 from tensorflow.python.layers import layers

~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/__init__.py in <module>
     25 
     26 # See b/110718070#comment18 for more details about this import.
---> 27 from tensorflow.python.keras import models
     28 
     29 from tensorflow.python.keras.engine.input_layer import Input

~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/models.py in <module>
     22 from tensorflow.python.framework import ops
     23 from tensorflow.python.keras import backend as K
---> 24 from tensorflow.python.keras import metrics as metrics_module
     25 from tensorflow.python.keras import optimizers
     26 from tensorflow.python.keras.engine import network

~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/metrics.py in <module>
     35 from tensorflow.python.framework import tensor_spec
     36 from tensorflow.python.keras import backend as K
---> 37 from tensorflow.python.keras.engine import base_layer
     38 from tensorflow.python.keras.engine import base_layer_utils
     39 from tensorflow.python.keras.losses import binary_crossentropy

~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer.py in <module>
     49 from tensorflow.python.keras import backend
     50 from tensorflow.python.keras import constraints
---> 51 from tensorflow.python.keras import initializers
     52 from tensorflow.python.keras import regularizers
     53 from tensorflow.python.keras.engine import base_layer_utils

~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/initializers/__init__.py in <module>
    125 # from ALL_OBJECTS. We make no guarantees as to whether these objects will
    126 # using their correct version.
--> 127 populate_deserializable_objects()
    128 globals().update(LOCAL.ALL_OBJECTS)
    129 

~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/initializers/__init__.py in populate_deserializable_objects()
     83     v2_objs = {}
     84     base_cls = initializers_v2.Initializer
---> 85     generic_utils.populate_dict_with_module_objects(
     86         v2_objs,
     87         [initializers_v2],

AttributeError: module 'tensorflow.python.keras.utils.generic_utils' has no attribute 'populate_dict_with_module_objects'

#import tensorflow as tf
from tensorflow import keras

config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

---------------------------------------------------------------------------
AttributeError                            Traceback (most recent call last)
<ipython-input-6-bc61f24dae51> in <module>
      1 #import tensorflow as tf
----> 2 from tensorflow import keras
      3 
      4 config = tf.compat.v1.ConfigProto()
      5 config.gpu_options.allow_growth = True

~/anaconda3/lib/python3.7/site-packages/tensorflow/__init__.py in <module>
     39 import sys as _sys
     40 
---> 41 from tensorflow.python.tools import module_util as _module_util
     42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
     43 

~/anaconda3/lib/python3.7/site-packages/tensorflow/python/__init__.py in <module>
     82 from tensorflow.python import data
     83 from tensorflow.python import distribute
---> 84 from tensorflow.python import keras
     85 from tensorflow.python.feature_column import feature_column_lib as feature_column
     86 from tensorflow.python.layers import layers

~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/__init__.py in <module>
     25 
     26 # See b/110718070#comment18 for more details about this import.
---> 27 from tensorflow.python.keras import models
     28 
     29 from tensorflow.python.keras.engine.input_layer import Input

~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/models.py in <module>
     22 from tensorflow.python.framework import ops
     23 from tensorflow.python.keras import backend as K
---> 24 from tensorflow.python.keras import metrics as metrics_module
     25 from tensorflow.python.keras import optimizers
     26 from tensorflow.python.keras.engine import network

~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/metrics.py in <module>
     35 from tensorflow.python.framework import tensor_spec
     36 from tensorflow.python.keras import backend as K
---> 37 from tensorflow.python.keras.engine import base_layer
     38 from tensorflow.python.keras.engine import base_layer_utils
     39 from tensorflow.python.keras.losses import binary_crossentropy

~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer.py in <module>
     49 from tensorflow.python.keras import backend
     50 from tensorflow.python.keras import constraints
---> 51 from tensorflow.python.keras import initializers
     52 from tensorflow.python.keras import regularizers
     53 from tensorflow.python.keras.engine import base_layer_utils

~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/initializers/__init__.py in <module>
    125 # from ALL_OBJECTS. We make no guarantees as to whether these objects will
    126 # using their correct version.
--> 127 populate_deserializable_objects()
    128 globals().update(LOCAL.ALL_OBJECTS)
    129 

~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/initializers/__init__.py in populate_deserializable_objects()
     83     v2_objs = {}
     84     base_cls = initializers_v2.Initializer
---> 85     generic_utils.populate_dict_with_module_objects(
     86         v2_objs,
     87         [initializers_v2],

AttributeError: module 'tensorflow.python.keras.utils.generic_utils' has no attribute 'populate_dict_with_module_objects'

# !pip install https://storage.googleapis.com/bert_models/2018_11_23/multi_cased_L-12_H-768_A-12.zip

Collecting https://storage.googleapis.com/bert_models/2018_11_23/multi_cased_L-12_H-768_A-12.zip
  Using cached https://storage.googleapis.com/bert_models/2018_11_23/multi_cased_L-12_H-768_A-12.zip (662.9 MB)
    ERROR: Command errored out with exit status 1:
     command: /home/ubuntu/virt-env/bin/python3 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-req-build-pat2nar8/setup.py'"'"'; __file__='"'"'/tmp/pip-req-build-pat2nar8/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-md3sygo6
         cwd: /tmp/pip-req-build-pat2nar8/
    Complete output (5 lines):
    Traceback (most recent call last):
      File "<string>", line 1, in <module>
      File "/usr/lib/python3.6/tokenize.py", line 452, in open
        buffer = _builtin_open(filename, 'rb')
    FileNotFoundError: [Errno 2] No such file or directory: '/tmp/pip-req-build-pat2nar8/setup.py'
    ----------------------------------------
ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.

pip install --no-cache-dir https://storage.googleapis.com/bert_models/2018_11_23/multi_cased_L-12_H-768_A-12.zip

Collecting https://storage.googleapis.com/bert_models/2018_11_23/multi_cased_L-12_H-768_A-12.z
using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
Collecting six>=1.12.0
  Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
Collecting tensorflow-estimator<2.3.0,>=2.2.0
  Using cached tensorflow_estimator-2.2.0-py2.py3-none-any.whl (454 kB)
Collecting scipy==1.4.1; python_version >= "3"
  Using cached scipy-1.4.1-cp37-cp37m-manylinux1_x86_64.whl (26.1 MB)
Collecting protobuf>=3.8.0
  Using cached protobuf-3.12.2-cp37-cp37m-manylinux1_x86_64.whl (1.3 MB)
Collecting astunparse==1.6.3
  Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
Collecting keras-preprocessing>=1.1.0
  Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
Collecting markdown>=2.6.8
  Using cached Markdown-3.2.2-py3-none-any.whl (88 kB)
Collecting google-auth-oauthlib<0.5,>=0.4.1
  Using cached google_auth_oauthlib-0.4.1-py2.py3-none-any.whl (18 kB)
Collecting werkzeug>=0.11.15
  Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
     |████████████████████████████████| 298 kB 33.4 MB/s eta 0:00:01
Collecting setuptools>=41.0.0
  Using cached setuptools-49.1.1-py3-none-any.whl (789 kB)
Collecting google-auth<2,>=1.6.3
  Using cached google_auth-1.18.0-py2.py3-none-any.whl (90 kB)
Collecting tensorboard-plugin-wit>=1.6.0
  Downloading tensorboard_plugin_wit-1.7.0-py3-none-any.whl (779 kB)
     |████████████████████████████████| 779 kB 36.3 MB/s eta 0:00:01
Collecting requests<3,>=2.21.0
  Using cached requests-2.24.0-py2.py3-none-any.whl (61 kB)
Collecting importlib-metadata; python_version < "3.8"
  Downloading importlib_metadata-1.7.0-py2.py3-none-any.whl (31 kB)
Collecting requests-oauthlib>=0.7.0
  Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
Collecting rsa<5,>=3.1.4; python_version >= "3"
  Using cached rsa-4.6-py3-none-any.whl (47 kB)
Collecting pyasn1-modules>=0.2.1
  Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
Collecting cachetools<5.0,>=2.0.0
  Downloading cachetools-4.1.1-py3-none-any.whl (10 kB)
Collecting chardet<4,>=3.0.2
  Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
Collecting certifi>=2017.4.17
  Using cached certifi-2020.6.20-py2.py3-none-any.whl (156 kB)
Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
  Using cached urllib3-1.25.9-py2.py3-none-any.whl (126 kB)
Collecting idna<3,>=2.5
  Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
Collecting zipp>=0.5
  Downloading zipp-3.1.0-py3-none-any.whl (4.9 kB)
Collecting oauthlib>=3.0.0
  Using cached oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
Collecting pyasn1>=0.1.3
  Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
Building wheels for collected packages: wrapt
  Building wheel for wrapt (setup.py) ... done
  Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=70960 sha256=ab9681a4c805349d85d5762e4645cfc3b0bea6f369531d3e33a6aee893ba5f06
  Stored in directory: /home/ubuntu/.cache/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
Successfully built wrapt
ERROR: spyder 3.3.6 requires pyqt5<5.13; python_version >= "3", which is not installed.
ERROR: spyder 3.3.6 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
ERROR: astroid 2.3.1 requires typed-ast<1.5,>=1.4.0; implementation_name == "cpython" and python_version < "3.8", which is not installed.
ERROR: tf-nightly 2.4.0.dev20200706 has requirement numpy<1.19.0,>=1.16.0, but you'll have numpy 1.19.0 which is incompatible.
ERROR: tf-nightly-gpu 2.4.0.dev20200707 has requirement numpy<1.19.0,>=1.16.0, but you'll have numpy 1.19.0 which is incompatible.
ERROR: kaggle 1.5.6 has requirement urllib3<1.25,>=1.21.1, but you'll have urllib3 1.25.9 which is incompatible.
ERROR: astroid 2.3.1 has requirement six==1.12, but you'll have six 1.15.0 which is incompatible.
ERROR: astroid 2.3.1 has requirement wrapt==1.11.*, but you'll have wrapt 1.12.1 which is incompatible.
Installing collected packages: wrapt, gast, termcolor, six, grpcio, numpy, wheel, zipp, importlib-metadata, markdown, pyasn1, rsa, pyasn1-modules, cachetools, setuptools, google-auth, oauthlib, chardet, certifi, urllib3, idna, requests, requests-oauthlib, google-auth-oauthlib, werkzeug, absl-py, tensorboard-plugin-wit, protobuf, tensorboard, h5py, opt-einsum, google-pasta, tensorflow-estimator, scipy, astunparse, keras-preprocessing, tensorflow-gpu
  Attempting uninstall: wrapt
    Found existing installation: wrapt 1.11.2
    Uninstalling wrapt-1.11.2:
      Successfully uninstalled wrapt-1.11.2
  Attempting uninstall: gast
    Found existing installation: gast 0.3.3
    Uninstalling gast-0.3.3:
      Successfully uninstalled gast-0.3.3
  Attempting uninstall: termcolor
    Found existing installation: termcolor 1.1.0
    Uninstalling termcolor-1.1.0:
      Successfully uninstalled termcolor-1.1.0
  Attempting uninstall: six
    Found existing installation: six 1.12.0
    Uninstalling six-1.12.0:
      Successfully uninstalled six-1.12.0
  Attempting uninstall: grpcio
    Found existing installation: grpcio 1.30.0
    Uninstalling grpcio-1.30.0:
      Successfully uninstalled grpcio-1.30.0
  Attempting uninstall: numpy
    Found existing installation: numpy 1.17.2
    Uninstalling numpy-1.17.2:
      Successfully uninstalled numpy-1.17.2
  Attempting uninstall: wheel
    Found existing installation: wheel 0.33.6
    Uninstalling wheel-0.33.6:
      Successfully uninstalled wheel-0.33.6
  Attempting uninstall: zipp
    Found existing installation: zipp 0.6.0
    Uninstalling zipp-0.6.0:
      Successfully uninstalled zipp-0.6.0
  Attempting uninstall: importlib-metadata
    Found existing installation: importlib-metadata 0.23
    Uninstalling importlib-metadata-0.23:
      Successfully uninstalled importlib-metadata-0.23
  Attempting uninstall: markdown
    Found existing installation: Markdown 3.2.2
    Uninstalling Markdown-3.2.2:
      Successfully uninstalled Markdown-3.2.2
  Attempting uninstall: pyasn1
    Found existing installation: pyasn1 0.4.8
    Uninstalling pyasn1-0.4.8:
      Successfully uninstalled pyasn1-0.4.8
  Attempting uninstall: rsa
    Found existing installation: rsa 4.6
    Uninstalling rsa-4.6:
      Successfully uninstalled rsa-4.6
  Attempting uninstall: pyasn1-modules
    Found existing installation: pyasn1-modules 0.2.8
    Uninstalling pyasn1-modules-0.2.8:
      Successfully uninstalled pyasn1-modules-0.2.8
  Attempting uninstall: cachetools
    Found existing installation: cachetools 4.1.0
    Uninstalling cachetools-4.1.0:
      Successfully uninstalled cachetools-4.1.0
  Attempting uninstall: setuptools
    Found existing installation: setuptools 49.1.1
    Uninstalling setuptools-49.1.1:
      Successfully uninstalled setuptools-49.1.1
  Attempting uninstall: google-auth
    Found existing installation: google-auth 1.18.0
    Uninstalling google-auth-1.18.0:
      Successfully uninstalled google-auth-1.18.0
  Attempting uninstall: oauthlib
    Found existing installation: oauthlib 3.1.0
    Uninstalling oauthlib-3.1.0:
      Successfully uninstalled oauthlib-3.1.0
  Attempting uninstall: chardet
    Found existing installation: chardet 3.0.4
    Uninstalling chardet-3.0.4:
      Successfully uninstalled chardet-3.0.4
  Attempting uninstall: certifi
    Found existing installation: certifi 2019.9.11
    Uninstalling certifi-2019.9.11:
      Successfully uninstalled certifi-2019.9.11
  Attempting uninstall: urllib3
    Found existing installation: urllib3 1.24.2
    Uninstalling urllib3-1.24.2:
      Successfully uninstalled urllib3-1.24.2
  Attempting uninstall: idna
    Found existing installation: idna 2.8
    Uninstalling idna-2.8:
      Successfully uninstalled idna-2.8
  Attempting uninstall: requests
    Found existing installation: requests 2.22.0
    Uninstalling requests-2.22.0:
      Successfully uninstalled requests-2.22.0
  Attempting uninstall: requests-oauthlib
    Found existing installation: requests-oauthlib 1.3.0
    Uninstalling requests-oauthlib-1.3.0:
      Successfully uninstalled requests-oauthlib-1.3.0
  Attempting uninstall: google-auth-oauthlib
    Found existing installation: google-auth-oauthlib 0.4.1
    Uninstalling google-auth-oauthlib-0.4.1:
      Successfully uninstalled google-auth-oauthlib-0.4.1
  Attempting uninstall: werkzeug
    Found existing installation: Werkzeug 0.16.0
    Uninstalling Werkzeug-0.16.0:
      Successfully uninstalled Werkzeug-0.16.0
  Attempting uninstall: absl-py
    Found existing installation: absl-py 0.9.0
    Uninstalling absl-py-0.9.0:
      Successfully uninstalled absl-py-0.9.0
  Attempting uninstall: tensorboard-plugin-wit
    Found existing installation: tensorboard-plugin-wit 1.6.0.post3
    Uninstalling tensorboard-plugin-wit-1.6.0.post3:
      Successfully uninstalled tensorboard-plugin-wit-1.6.0.post3
  Attempting uninstall: protobuf
    Found existing installation: protobuf 3.12.2
    Uninstalling protobuf-3.12.2:
      Successfully uninstalled protobuf-3.12.2
  Attempting uninstall: tensorboard
    Found existing installation: tensorboard 2.2.2
    Uninstalling tensorboard-2.2.2:
      Successfully uninstalled tensorboard-2.2.2
  Attempting uninstall: h5py
    Found existing installation: h5py 2.10.0
    Uninstalling h5py-2.10.0:
      Successfully uninstalled h5py-2.10.0
  Attempting uninstall: opt-einsum
    Found existing installation: opt-einsum 3.2.1
    Uninstalling opt-einsum-3.2.1:
      Successfully uninstalled opt-einsum-3.2.1
  Attempting uninstall: google-pasta
    Found existing installation: google-pasta 0.2.0
    Uninstalling google-pasta-0.2.0:
      Successfully uninstalled google-pasta-0.2.0
  Attempting uninstall: tensorflow-estimator
    Found existing installation: tensorflow-estimator 2.2.0
    Uninstalling tensorflow-estimator-2.2.0:
      Successfully uninstalled tensorflow-estimator-2.2.0
  Attempting uninstall: scipy
    Found existing installation: scipy 1.4.1
    Uninstalling scipy-1.4.1:
      Successfully uninstalled scipy-1.4.1
  Attempting uninstall: astunparse
    Found existing installation: astunparse 1.6.3
    Uninstalling astunparse-1.6.3:
      Successfully uninstalled astunparse-1.6.3
  Attempting uninstall: keras-preprocessing
    Found existing installation: Keras-Preprocessing 1.1.2
    Uninstalling Keras-Preprocessing-1.1.2:
      Successfully uninstalled Keras-Preprocessing-1.1.2
Successfully installed absl-py-0.9.0 astunparse-1.6.3 cachetools-4.1.1 certifi-2020.6.20 chardet-3.0.4 gast-0.3.3 google-auth-1.18.0 google-auth-oauthlib-0.4.1 google-pasta-0.2.0 grpcio-1.30.0 h5py-2.10.0 idna-2.10 importlib-metadata-1.7.0 keras-preprocessing-1.1.2 markdown-3.2.2 numpy-1.19.0 oauthlib-3.1.0 opt-einsum-3.2.1 protobuf-3.12.2 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-2.24.0 requests-oauthlib-1.3.0 rsa-4.6 scipy-1.4.1 setuptools-49.1.1 six-1.15.0 tensorboard-2.2.2 tensorboard-plugin-wit-1.7.0 tensorflow-estimator-2.2.0 tensorflow-gpu-2.2.0 termcolor-1.1.0 urllib3-1.25.9 werkzeug-1.0.1 wheel-0.34.2 wrapt-1.12.1 zipp-3.1.0
Note: you may need to restart the kernel to use updated packages.

import tensorflow as tf
print(tf.version.VERSION)

2.2.0

pip install --user --upgrade tensorflow

Collecting tensorflow
  Using cached tensorflow-2.2.0-cp37-cp37m-manylinux2010_x86_64.whl (516.2 MB)
Requirement already satisfied, skipping upgrade: absl-py>=0.7.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow) (0.9.0)
Requirement already satisfied, skipping upgrade: numpy<2.0,>=1.16.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.19.0)
Requirement already satisfied, skipping upgrade: protobuf>=3.8.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow) (3.12.2)
Requirement already satisfied, skipping upgrade: wheel>=0.26; python_version >= "3" in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow) (0.34.2)
Requirement already satisfied, skipping upgrade: h5py<2.11.0,>=2.10.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow) (2.10.0)
Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.1.0)
Requirement already satisfied, skipping upgrade: six>=1.12.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.15.0)
Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.30.0)
Requirement already satisfied, skipping upgrade: scipy==1.4.1; python_version >= "3" in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.4.1)
Collecting tensorboard<2.3.0,>=2.2.0
  Using cached tensorboard-2.2.2-py3-none-any.whl (3.0 MB)
Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow) (3.2.1)
Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.12.1)
Requirement already satisfied, skipping upgrade: google-pasta>=0.1.8 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow) (0.2.0)
Requirement already satisfied, skipping upgrade: astunparse==1.6.3 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.6.3)
Requirement already satisfied, skipping upgrade: gast==0.3.3 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow) (0.3.3)
Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.1.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.1.2)
Collecting tensorflow-estimator<2.3.0,>=2.2.0
  Using cached tensorflow_estimator-2.2.0-py2.py3-none-any.whl (454 kB)
Requirement already satisfied, skipping upgrade: setuptools in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from protobuf>=3.8.0->tensorflow) (49.1.1)
Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (2.24.0)
Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (0.4.1)
Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (1.18.0)
Requirement already satisfied, skipping upgrade: tensorboard-plugin-wit>=1.6.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (1.7.0)
Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (1.0.1)
Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (3.2.2)
Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (2020.6.20)
Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (1.25.9)
Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (3.0.4)
Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (2.10)
Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow) (1.3.0)
Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (0.2.8)
Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (4.1.1)
Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3" in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (4.6)
Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow) (1.7.0)
Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow) (3.1.0)
Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (0.4.8)
Requirement already satisfied, skipping upgrade: zipp>=0.5 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow) (3.1.0)
Installing collected packages: tensorboard, tensorflow-estimator, tensorflow
  WARNING: The script tensorboard is installed in '/home/ubuntu/.local/bin' which is not on PATH.
  Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
  WARNING: The scripts estimator_ckpt_converter, saved_model_cli, tensorboard, tf_upgrade_v2, tflite_convert, toco and toco_from_protos are installed in '/home/ubuntu/.local/bin' which is not on PATH.
  Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
Successfully installed tensorboard-2.2.2 tensorflow-2.2.0 tensorflow-estimator-2.2.0
Note: you may need to restart the kernel to use updated packages.

 

2.2.0

 

from bert_serving.client import BertClient
bc = BertClient(ip='129.128.208.15')
print('client inited.')

---------------------------------------------------------------------------
KeyboardInterrupt                         Traceback (most recent call last)
<ipython-input-1-9df503aa9fab> in <module>
      1 from bert_serving.client import BertClient
----> 2 bc = BertClient(ip='129.128.208.15')
      3 print('client inited.')

~/anaconda3/lib/python3.7/site-packages/bert_serving/client/__init__.py in __init__(self, ip, port, port_out, output_fmt, show_server_config, identity, check_version, check_length, check_token_info, ignore_all_checks, timeout)
    106 
    107         if not ignore_all_checks and (check_version or show_server_config or check_length or check_token_info):
--> 108             s_status = self.server_config
    109 
    110             if check_version and s_status['server_version'] != self.status['client_version']:

~/anaconda3/lib/python3.7/site-packages/bert_serving/client/__init__.py in arg_wrapper(self, *args, **kwargs)
    204                 self.receiver.setsockopt(zmq.RCVTIMEO, self.timeout)
    205             try:
--> 206                 return func(self, *args, **kwargs)
    207             except zmq.error.Again as _e:
    208                 t_e = TimeoutError(

~/anaconda3/lib/python3.7/site-packages/bert_serving/client/__init__.py in server_config(self)
    230         """
    231         req_id = self._send(b'SHOW_CONFIG')
--> 232         return jsonapi.loads(self._recv(req_id).content[1])
    233 
    234     @property

~/anaconda3/lib/python3.7/site-packages/bert_serving/client/__init__.py in _recv(self, wait_for_req_id)
    151 
    152                 # receive a response
--> 153                 response = self.receiver.recv_multipart()
    154                 request_id = int(response[-1])
    155 

~/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
    473             for any of the reasons :func:`~Socket.recv` might fail
    474         """
--> 475         parts = [self.recv(flags, copy=copy, track=track)]
    476         # have first part already, only loop while more to receive
    477         while self.getsockopt(zmq.RCVMORE):

zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()

zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()

zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()

~/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()

KeyboardInterrupt: 

# !wget https://tfhub.dev/tensorflow/albert_en_base/1 -O temp

--2020-07-14 00:12:12--  https://tfhub.dev/tensorflow/albert_en_base/1
Resolving tfhub.dev (tfhub.dev)... 172.217.3.174, 2607:f8b0:400a:804::200e
Connecting to tfhub.dev (tfhub.dev)|172.217.3.174|:443... connected.
HTTP request sent, awaiting response... 200 OK
Length: unspecified [text/html]
Saving to: ‘temp’

temp                    [ <=>                ]   1.20K  --.-KB/s    in 0s      

2020-07-14 00:12:12 (18.1 MB/s) - ‘temp’ saved [1229]

ls

1    1.tar       NLP_4_1.ipynb  Sae-NLP1.ipynb  temp             Untitled.ipynb
1.1  bert_repo/  Sae/           Sae-P2.ipynb    Untitled1.ipynb

max_seq_length = 128

input_word_ids = tf.keras.layers.Input(shape=(max_seq_length,), dtype=tf.int32, name="input_word_ids")

input_mask = tf.keras.layers.Input(shape=(max_seq_length,), dtype=tf.int32, name="input_mask")

segment_ids = tf.keras.layers.Input(shape=(max_seq_length,), dtype=tf.int32, name="segment_ids")

import tensorflow_hub as hub

albert_layer = hub.KerasLayer("https://tfhub.dev/tensorflow/albert_en_base/1", trainable=True)

pooled_output, sequence_output = albert_layer([input_word_ids, input_mask, segment_ids])

pooled_output

<tf.Tensor 'keras_layer/Identity:0' shape=(None, 768) dtype=float32>

sequence_output

<tf.Tensor 'keras_layer/Identity_1:0' shape=(None, None, 768) dtype=float32>

sp_model_file = albert_layer.resolved_object.sp_model_file.asset_path.numpy()

tokenizer = tokenization.FullSentencePieceTokenizer(sp_model_file)

---------------------------------------------------------------------------
NameError                                 Traceback (most recent call last)
<ipython-input-33-0782b4971b42> in <module>
----> 1 tokenizer = tokenization.FullSentencePieceTokenizer(sp_model_file)

NameError: name 'tokenization' is not defined

import sys
import time

from random import choice
import string

import numpy as np

from service.client import BertClient

def GenRandomText(length=8, chars=string.ascii_letters + string.digits):
    return ''.join([choice(chars) for i in range(length)])

def cosine_sim(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

if __name__ == '__main__':
    from service.client import BertClient
    bc = BertClient(ip='localhost', port=5555)

    for i in range(1, 10):
        
        leftTerm = GenRandomText(3,string.ascii_letters)
        rightTerm = "how are you today?"

        leftV = bc.encode([leftTerm])
        rightV = bc.encode([rightTerm ])

        cosine_similarity = cosine_sim(leftV[0],rightV[0])
        
        print("left: %s right: %s distance: %f" % (leftTerm,rightTerm,cosine_similarity) )

---------------------------------------------------------------------------
ModuleNotFoundError                       Traceback (most recent call last)
<ipython-input-5-3e1082fe35db> in <module>
      7 import numpy as np
      8 
----> 9 from service.client import BertClient
     10 
     11 def GenRandomText(length=8, chars=string.ascii_letters + string.digits):

ModuleNotFoundError: No module named 'service'

from bert_serving.client import BertClient

ec = BertClient()
print("sss")

---------------------------------------------------------------------------
KeyboardInterrupt                         Traceback (most recent call last)
<ipython-input-25-4aedc267d559> in <module>
----> 1 ec = BertClient()
      2 print("sss")

~/anaconda3/lib/python3.7/site-packages/bert_serving/client/__init__.py in __init__(self, ip, port, port_out, output_fmt, show_server_config, identity, check_version, check_length, check_token_info, ignore_all_checks, timeout)
    106 
    107         if not ignore_all_checks and (check_version or show_server_config or check_length or check_token_info):
--> 108             s_status = self.server_config
    109 
    110             if check_version and s_status['server_version'] != self.status['client_version']:

~/anaconda3/lib/python3.7/site-packages/bert_serving/client/__init__.py in arg_wrapper(self, *args, **kwargs)
    204                 self.receiver.setsockopt(zmq.RCVTIMEO, self.timeout)
    205             try:
--> 206                 return func(self, *args, **kwargs)
    207             except zmq.error.Again as _e:
    208                 t_e = TimeoutError(

~/anaconda3/lib/python3.7/site-packages/bert_serving/client/__init__.py in server_config(self)
    230         """
    231         req_id = self._send(b'SHOW_CONFIG')
--> 232         return jsonapi.loads(self._recv(req_id).content[1])
    233 
    234     @property

~/anaconda3/lib/python3.7/site-packages/bert_serving/client/__init__.py in _recv(self, wait_for_req_id)
    151 
    152                 # receive a response
--> 153                 response = self.receiver.recv_multipart()
    154                 request_id = int(response[-1])
    155 

~/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
    473             for any of the reasons :func:`~Socket.recv` might fail
    474         """
--> 475         parts = [self.recv(flags, copy=copy, track=track)]
    476         # have first part already, only loop while more to receive
    477         while self.getsockopt(zmq.RCVMORE):

zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()

zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()

zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()

~/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()

KeyboardInterrupt: 

import uuid

import numpy as np
import zmq
from zmq.utils import jsonapi


class BertClient:
    def __init__(self, ip='localhost', port=8888, output_fmt='ndarray', show_server_config=True):
        self.socket = zmq.Context().socket(zmq.REQ)
        self.socket.identity = str(uuid.uuid4()).encode('ascii')
        self.socket.connect('tcp://%s:%d' % (ip, port))
        self.ip = ip
        self.port = port

        if output_fmt == 'ndarray':
            self.formatter = lambda x: x
        elif output_fmt == 'list':
            self.formatter = lambda x: x.tolist()
        else:
            raise AttributeError('"output_fmt" must be "ndarray" or "list"')

        if show_server_config:
            self.get_server_config()
            print('you should NOT see this message multiple times! '
                  'if you see it appears repeatedly, '
                  'please consider moving "BertClient()" out of the loop.')

    def get_server_config(self):
        self.socket.send(b'SHOW_CONFIG')
        response = self.socket.recv_multipart()
        print('the server at %s:%d returns the following config:' % (self.ip, self.port))
        for k, v in jsonapi.loads(response[0]).items():
            print('%30s\t=\t%-30s' % (k, v))

    def encode(self, texts):
        if self.is_valid_input(texts):
            self.socket.send_pyobj(texts)
            response = self.socket.recv_multipart()
            arr_info, arr_val = jsonapi.loads(response[0]), response[3]
            X = np.frombuffer(memoryview(arr_val), dtype=arr_info['dtype'])
            return self.formatter(X.reshape(arr_info['shape']))
        else:
            raise AttributeError('"texts" must be "List[str]" and non-empty!')

    @staticmethod
    def is_valid_input(texts):
        return isinstance(texts, list) and all(isinstance(s, str) and s.strip() for s in texts)

# !wget https://github.com/jageshmaharjan/BERT_Service/archive/master.zip -O tmp2.zip

--2020-07-14 06:03:51--  https://github.com/jageshmaharjan/BERT_Service/archive/master.zip
Resolving github.com (github.com)... 140.82.114.3
Connecting to github.com (github.com)|140.82.114.3|:443... connected.
HTTP request sent, awaiting response... 302 Found
Location: https://codeload.github.com/jageshmaharjan/BERT_Service/zip/master [following]
--2020-07-14 06:03:51--  https://codeload.github.com/jageshmaharjan/BERT_Service/zip/master
Resolving codeload.github.com (codeload.github.com)... 140.82.112.9
Connecting to codeload.github.com (codeload.github.com)|140.82.112.9|:443... connected.
HTTP request sent, awaiting response... 200 OK
Length: unspecified [application/zip]
Saving to: ‘tmp2.zip’

tmp2.zip                [  <=>               ] 234.69K  1.02MB/s    in 0.2s    

2020-07-14 06:03:52 (1.02 MB/s) - ‘tmp2.zip’ saved [240320]

# !unzip tmp2.zip

Archive:  tmp2.zip
06f0059e1ab8781d524f4698b2e8a742cacbd796
   creating: BERT_Service-master/
   creating: BERT_Service-master/.github/
   creating: BERT_Service-master/.github/workflows/
  inflating: BERT_Service-master/.github/workflows/blank.yml  
  inflating: BERT_Service-master/=   
  inflating: BERT_Service-master/BERT_sentence_similarity.ipynb  
  inflating: BERT_Service-master/LICENSE  
  inflating: BERT_Service-master/README.md  
  inflating: BERT_Service-master/Word2Vec.ipynb  
  inflating: BERT_Service-master/__init__.py  
  inflating: BERT_Service-master/app.py  
  inflating: BERT_Service-master/azure-pipelines.yml  
  inflating: BERT_Service-master/benchmark.py  
   creating: BERT_Service-master/bert/
  inflating: BERT_Service-master/bert/__init__.py  
  inflating: BERT_Service-master/bert/extract_features.py  
  inflating: BERT_Service-master/bert/modeling.py  
  inflating: BERT_Service-master/bert/modeling_test.py  
  inflating: BERT_Service-master/bert/optimization.py  
  inflating: BERT_Service-master/bert/optimization_test.py  
  inflating: BERT_Service-master/bert/tokenization.py  
  inflating: BERT_Service-master/bert/tokenization_test.py  
  inflating: BERT_Service-master/client_example.py  
   creating: BERT_Service-master/docker/
  inflating: BERT_Service-master/docker/Dockerfile  
  inflating: BERT_Service-master/docker/entrypoint.sh  
  inflating: BERT_Service-master/gpu_env.py  
  inflating: BERT_Service-master/helper.py  
   creating: BERT_Service-master/manifests/
  inflating: BERT_Service-master/manifests/deployment.yml  
  inflating: BERT_Service-master/manifests/service.yml  
  inflating: BERT_Service-master/requirements.client.txt  
  inflating: BERT_Service-master/requirements.gpu.txt  
  inflating: BERT_Service-master/requirements.txt  
   creating: BERT_Service-master/service/
 extracting: BERT_Service-master/service/__init__.py  
  inflating: BERT_Service-master/service/client.py  
  inflating: BERT_Service-master/service/server.py  

ls

1      bert_repo/            Sae/            temp             Untitled.ipynb
1.1    BERT_Service-master/  Sae-NLP1.ipynb  tmp2.zip
1.tar  NLP_4_1.ipynb         Sae-P2.ipynb    Untitled1.ipynb

# !bert-serving-start -num_worker=4 -model_dir /uncased_L-24_H-1024_A-16/

/home/ubuntu/anaconda3/lib/python3.7/site-packages/bert_serving/server/helper.py:176: UserWarning: Tensorflow 2.2.0 is not tested! It may or may not work. Feel free to submit an issue at https://github.com/hanxiao/bert-as-service/issues/
  'Feel free to submit an issue at https://github.com/hanxiao/bert-as-service/issues/' % tf.__version__)
usage: /home/ubuntu/anaconda3/bin/bert-serving-start -num_worker=4 -model_dir /uncased_L-24_H-1024_A-16/
                 ARG   VALUE
__________________________________________________
           ckpt_name = bert_model.ckpt
         config_name = bert_config.json
                cors = *
                 cpu = False
          device_map = []
       do_lower_case = True
  fixed_embed_length = False
                fp16 = False
 gpu_memory_fraction = 0.5
       graph_tmp_dir = None
    http_max_connect = 10
           http_port = None
        mask_cls_sep = False
      max_batch_size = 256
         max_seq_len = 25
           model_dir = /uncased_L-24_H-1024_A-16/
no_position_embeddings = False
    no_special_token = False
          num_worker = 4
       pooling_layer = [-2]
    pooling_strategy = REDUCE_MEAN
                port = 5555
            port_out = 5556
       prefetch_size = 10
 priority_batch_size = 16
show_tokens_to_client = False
     tuned_model_dir = None
             verbose = False
                 xla = False

I:VENTILATOR:[__i:__i: 67]:freeze, optimize and export graph, could take a while...
I:GRAPHOPT:[gra:opt: 53]:model config: /uncased_L-24_H-1024_A-16/bert_config.json
I:GRAPHOPT:[gra:opt: 56]:checkpoint: /uncased_L-24_H-1024_A-16/bert_model.ckpt
E:GRAPHOPT:[gra:opt:154]:fail to optimize the graph!
Traceback (most recent call last):
  File "/home/ubuntu/anaconda3/lib/python3.7/site-packages/bert_serving/server/graph.py", line 58, in optimize_graph
    bert_config = modeling.BertConfig.from_dict(json.load(f))
  File "/home/ubuntu/anaconda3/lib/python3.7/json/__init__.py", line 293, in load
    return loads(fp.read(),
  File "/home/ubuntu/.local/lib/python3.7/site-packages/tensorflow/python/lib/io/file_io.py", line 116, in read
    self._preread_check()
  File "/home/ubuntu/.local/lib/python3.7/site-packages/tensorflow/python/lib/io/file_io.py", line 79, in _preread_check
    self.__name, 1024 * 512)
tensorflow.python.framework.errors_impl.NotFoundError: /uncased_L-24_H-1024_A-16/bert_config.json; No such file or directory
Traceback (most recent call last):
  File "/home/ubuntu/anaconda3/bin/bert-serving-start", line 10, in <module>
    sys.exit(main())
  File "/home/ubuntu/anaconda3/lib/python3.7/site-packages/bert_serving/server/cli/__init__.py", line 4, in main
    with BertServer(get_run_args()) as server:
  File "/home/ubuntu/anaconda3/lib/python3.7/site-packages/bert_serving/server/__init__.py", line 71, in __init__
    self.graph_path, self.bert_config = pool.apply(optimize_graph, (self.args,))
TypeError: cannot unpack non-iterable NoneType object

# !bert-serving-start -model_dir /home/ubuntu/anaconda3/lib/python3.7/site-packages/uncased_L-24_H-1024_A-16/

/home/ubuntu/anaconda3/lib/python3.7/site-packages/bert_serving/server/helper.py:176: UserWarning: Tensorflow 2.2.0 is not tested! It may or may not work. Feel free to submit an issue at https://github.com/hanxiao/bert-as-service/issues/
  'Feel free to submit an issue at https://github.com/hanxiao/bert-as-service/issues/' % tf.__version__)
usage: /home/ubuntu/anaconda3/bin/bert-serving-start -model_dir /home/ubuntu/anaconda3/lib/python3.7/site-packages/uncased_L-24_H-1024_A-16/
                 ARG   VALUE
__________________________________________________
           ckpt_name = bert_model.ckpt
         config_name = bert_config.json
                cors = *
                 cpu = False
          device_map = []
       do_lower_case = True
  fixed_embed_length = False
                fp16 = False
 gpu_memory_fraction = 0.5
       graph_tmp_dir = None
    http_max_connect = 10
           http_port = None
        mask_cls_sep = False
      max_batch_size = 256
         max_seq_len = 25
           model_dir = /home/ubuntu/anaconda3/lib/python3.7/site-packages/uncased_L-24_H-1024_A-16/
no_position_embeddings = False
    no_special_token = False
          num_worker = 1
       pooling_layer = [-2]
    pooling_strategy = REDUCE_MEAN
                port = 5555
            port_out = 5556
       prefetch_size = 10
 priority_batch_size = 16
show_tokens_to_client = False
     tuned_model_dir = None
             verbose = False
                 xla = False

I:VENTILATOR:[__i:__i: 67]:freeze, optimize and export graph, could take a while...
I:GRAPHOPT:[gra:opt: 53]:model config: /home/ubuntu/anaconda3/lib/python3.7/site-packages/uncased_L-24_H-1024_A-16/bert_config.json
I:GRAPHOPT:[gra:opt: 56]:checkpoint: /home/ubuntu/anaconda3/lib/python3.7/site-packages/uncased_L-24_H-1024_A-16/bert_model.ckpt
I:GRAPHOPT:[gra:opt: 60]:build graph...
E:GRAPHOPT:[gra:opt:154]:fail to optimize the graph!
Traceback (most recent call last):
  File "/home/ubuntu/anaconda3/lib/python3.7/site-packages/bert_serving/server/graph.py", line 62, in optimize_graph
    input_ids = tf.compat.v1.placeholder(tf.int32, (None, None), 'input_ids')
  File "/home/ubuntu/.local/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py", line 3023, in placeholder
    raise RuntimeError("tf.compat.v1.placeholder() is not compatible with "
RuntimeError: tf.compat.v1.placeholder() is not compatible with eager execution.
Traceback (most recent call last):
  File "/home/ubuntu/anaconda3/bin/bert-serving-start", line 10, in <module>
    sys.exit(main())
  File "/home/ubuntu/anaconda3/lib/python3.7/site-packages/bert_serving/server/cli/__init__.py", line 4, in main
    with BertServer(get_run_args()) as server:
  File "/home/ubuntu/anaconda3/lib/python3.7/site-packages/bert_serving/server/__init__.py", line 71, in __init__
    self.graph_path, self.bert_config = pool.apply(optimize_graph, (self.args,))
TypeError: cannot unpack non-iterable NoneType object

# !sed -i 's/tf.placeholder/tf.compat.v1.placeholder/g' /home/ubuntu/.local/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py

ll

total 1315476
-rw-r--r-- 1 ubuntu        314 Oct 18  2018 bert_config.json
-rw-r--r-- 1 ubuntu 1344904432 Oct 18  2018 bert_model.ckpt.data-00000-of-00001
-rw-r--r-- 1 ubuntu      16530 Oct 18  2018 bert_model.ckpt.index
-rw-r--r-- 1 ubuntu    1878861 Oct 18  2018 bert_model.ckpt.meta
-rw-r--r-- 1 ubuntu     231508 Oct 18  2018 vocab.txt

pwd

'/home/ubuntu/anaconda3/lib/python3.7/site-packages/uncased_L-24_H-1024_A-16'

pip install tensorflow==1.13.1

Collecting tensorflow==1.13.1
  Using cached tensorflow-1.13.1-cp37-cp37m-manylinux1_x86_64.whl (92.6 MB)
Requirement already satisfied: astor>=0.6.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow==1.13.1) (0.8.1)
Requirement already satisfied: numpy>=1.13.3 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow==1.13.1) (1.19.0)
Requirement already satisfied: keras-preprocessing>=1.0.5 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow==1.13.1) (1.1.2)
Requirement already satisfied: six>=1.10.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow==1.13.1) (1.15.0)
Requirement already satisfied: absl-py>=0.1.6 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow==1.13.1) (0.9.0)
Requirement already satisfied: termcolor>=1.1.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow==1.13.1) (1.1.0)
Requirement already satisfied: grpcio>=1.8.6 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow==1.13.1) (1.30.0)
Requirement already satisfied: wheel>=0.26 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow==1.13.1) (0.34.2)
Requirement already satisfied: protobuf>=3.6.1 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow==1.13.1) (3.12.2)
Collecting tensorboard<1.14.0,>=1.13.0
  Using cached tensorboard-1.13.1-py3-none-any.whl (3.2 MB)
Collecting tensorflow-estimator<1.14.0rc0,>=1.13.0
  Using cached tensorflow_estimator-1.13.0-py2.py3-none-any.whl (367 kB)
Requirement already satisfied: gast>=0.2.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow==1.13.1) (0.3.3)
Requirement already satisfied: keras-applications>=1.0.6 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow==1.13.1) (1.0.8)
Requirement already satisfied: setuptools in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from protobuf>=3.6.1->tensorflow==1.13.1) (49.1.1)
Requirement already satisfied: werkzeug>=0.11.15 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (1.0.1)
Requirement already satisfied: markdown>=2.6.8 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (3.2.2)
Requirement already satisfied: mock>=2.0.0 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow==1.13.1) (3.0.5)
Requirement already satisfied: h5py in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from keras-applications>=1.0.6->tensorflow==1.13.1) (2.10.0)
Requirement already satisfied: importlib-metadata; python_version < "3.8" in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (1.7.0)
Requirement already satisfied: zipp>=0.5 in /home/ubuntu/anaconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (3.1.0)
ERROR: tensorflow-gpu 2.2.0 has requirement tensorboard<2.3.0,>=2.2.0, but you'll have tensorboard 1.13.1 which is incompatible.
ERROR: tensorflow-gpu 2.2.0 has requirement tensorflow-estimator<2.3.0,>=2.2.0, but you'll have tensorflow-estimator 1.13.0 which is incompatible.
Installing collected packages: tensorboard, tensorflow-estimator, tensorflow
  Attempting uninstall: tensorboard
    Found existing installation: tensorboard 2.2.2
    Uninstalling tensorboard-2.2.2:
      Successfully uninstalled tensorboard-2.2.2
  Attempting uninstall: tensorflow-estimator
    Found existing installation: tensorflow-estimator 2.2.0
    Uninstalling tensorflow-estimator-2.2.0:
      Successfully uninstalled tensorflow-estimator-2.2.0
  Attempting uninstall: tensorflow
    Found existing installation: tensorflow 2.2.0
    Uninstalling tensorflow-2.2.0:
      Successfully uninstalled tensorflow-2.2.0
Successfully installed tensorboard-1.13.1 tensorflow-1.13.1 tensorflow-estimator-1.14.0rc0
Note: you may need to restart the kernel to use updated packages.

import tensorflow as tf

pip install tensorflow-estimator==1.14.0rc

Collecting tensorflow-estimator==1.14.0rc0
  Downloading tensorflow_estimator-1.14.0rc0-py2.py3-none-any.whl (487 kB)
     |████████████████████████████████| 487 kB 1.8 MB/s eta 0:00:01
ERROR: tensorflow 1.13.1 has requirement tensorflow-estimator<1.14.0rc0,>=1.13.0, but you'll have tensorflow-estimator 1.14.0rc0 which is incompatible.
ERROR: tensorflow-gpu 2.2.0 has requirement tensorboard<2.3.0,>=2.2.0, but you'll have tensorboard 1.13.1 which is incompatible.
ERROR: tensorflow-gpu 2.2.0 has requirement tensorflow-estimator<2.3.0,>=2.2.0, but you'll have tensorflow-estimator 1.14.0rc0 which is incompatible.
Installing collected packages: tensorflow-estimator
  Attempting uninstall: tensorflow-estimator
    Found existing installation: tensorflow-estimator 1.13.0rc0
    Uninstalling tensorflow-estimator-1.13.0rc0:
      Successfully uninstalled tensorflow-estimator-1.13.0rc0
Successfully installed tensorflow-estimator-1.14.0rc0
Note: you may need to restart the kernel to use updated packages.

# !tf_upgrade_v2 --infile /home/ubuntu/anaconda3/lib/python3.7/site-packages/bert_serving/server/graph.py --outfile /home/ubuntu/.local/lib/python3.7/site-packages/tensorflow/tools/compatibility/tf_upgrade_v2_main.py

Traceback (most recent call last):
  File "/home/ubuntu/.local/bin/tf_upgrade_v2", line 5, in <module>
    from tensorflow.tools.compatibility.tf_upgrade_v2_main import main
  File "/home/ubuntu/.local/lib/python3.7/site-packages/tensorflow/tools/compatibility/tf_upgrade_v2_main.py", line 9, in <module>
    from .bert import modeling
ModuleNotFoundError: No module named 'tensorflow.tools.compatibility.bert'

 

ls

all_renames_v2.py  module_deprecations_v2.py  tf_upgrade_v2_main.py
ast_edits.py       __pycache__/               tf_upgrade_v2.py
__init__.py        renames_v2.py              tf_upgrade_v2_safety.py
ipynb.py           reorders_v2.py

SEQ_LEN = 128
BATCH_SIZE = 128
EPOCHS = 5
LR = 1e-4

import os

pretrained_path = 'uncased_L-12_H-768_A-12'
config_path = os.path.join(pretrained_path, 'bert_config.json')
checkpoint_path = os.path.join(pretrained_path, 'bert_model.ckpt')
vocab_path = os.path.join(pretrained_path, 'vocab.txt')

# TF_KERAS must be added to environment variables in order to use TPU
os.environ['TF_KERAS'] = '1'

import tensorflow as tf
from keras_bert import get_custom_objects

TPU_WORKER = 'grpc://' + os.environ['COLAB_TPU_ADDR']
resolver = tf.contrib.cluster_resolver.TPUClusterResolver(TPU_WORKER)
tf.contrib.distribute.initialize_tpu_system(resolver)
strategy = tf.contrib.distribute.TPUStrategy(resolver)

---------------------------------------------------------------------------
NameError                                 Traceback (most recent call last)
<ipython-input-1-5f27d03ebbff> in <module>
      2 from keras_bert import get_custom_objects
      3 
----> 4 TPU_WORKER = 'grpc://' + os.environ['COLAB_TPU_ADDR']
      5 resolver = tf.contrib.cluster_resolver.TPUClusterResolver(TPU_WORKER)
      6 tf.contrib.distribute.initialize_tpu_system(resolver)

NameError: name 'os' is not defined

import tensorflow as tf
print(tf.__version__)

2.2.0

import codecs
from keras_bert import load_trained_model_from_checkpoint

token_dict = {}
with codecs.open(vocab_path, 'r', 'utf8') as reader:
    for line in reader:
        token = line.strip()
        token_dict[token] = len(token_dict)

with strategy.scope():
    model = load_trained_model_from_checkpoint(
        config_path,
        checkpoint_path,
        training=True,
        trainable=True,
        seq_len=SEQ_LEN,
    )

---------------------------------------------------------------------------
NameError                                 Traceback (most recent call last)
<ipython-input-4-c8e0e56643e4> in <module>
      3 
      4 token_dict = {}
----> 5 with codecs.open(vocab_path, 'r', 'utf8') as reader:
      6     for line in reader:
      7         token = line.strip()

NameError: name 'vocab_path' is not defined

 

# !pip install tensorflow_estimator

Collecting tensorflow_estimator
  Using cached tensorflow_estimator-2.2.0-py2.py3-none-any.whl (454 kB)
Installing collected packages: tensorflow-estimator
Successfully installed tensorflow-estimator-2.2.0
